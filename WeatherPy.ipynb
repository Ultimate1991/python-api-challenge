# %% [markdown]
# # WeatherPy
# ----
#
# #### Note
# * Instructions have been included for each segment. You do not have to follow them exactly, but they are included to help you think through the steps.

# %%
# Dependencies and Setup
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import requests
import time
from scipy.stats import linregress

# Import API key
from api_keys import weather_api_key

# Incorporated citipy to determine city based on latitude and longitude
from citipy import citipy


# Output File (CSV)
output_data_file = "output_data/cities.csv"

# %% [markdown]
# ## Generate Cities List

# %%
# Create empty data frame and add columns for city, country, latitude and longitude
cities_list = pd.DataFrame()
cities_list["City"] = ""
cities_list["Country"] = ""
# Randomly generate numbers for latitude and longitude and loop through 500 times
cities_list["Latitude"] = [np.random.uniform(-70, 90) for x in range(1500)]
cities_list["Longitude"] = [np.random.uniform(-120, 180) for x in range(1500)]
# Use latitude and longitude to find city and country by using interrows and citipy
for index, row in cities_list.iterrows():
    lat = row["Latitude"]
    lng = row["Longitude"]
    cities_list.set_value(index, "City", citipy.nearest_city(lat, lng).city_name)
    cities_list.set_value(index, "Country", citipy.nearest_city(lat, lng).country_code)
# Delete any possible duplicate cities and reset index
cities_list = cities_list.drop_duplicates(["City", "Country"])
cities_list = cities_list.reset_index()
# Update data frame to just city and country column
cities_list = cities_list[["City", "Country", "Latitude", "Longitude",]]
cities_list = cities_list.iloc[:500]
cities_list
# Out:
# C:\Users\rtmcl\AppData\Local\Continuum\anaconda3\lib\site-packages\ipykernel_launcher.py:12: FutureWarning: set_value is deprecated and will be removed in a future release. Please use .at[] or .iat[] accessors instead
#   if sys.path[0] == '':
# C:\Users\rtmcl\AppData\Local\Continuum\anaconda3\lib\site-packages\ipykernel_launcher.py:13: FutureWarning: set_value is deprecated and will be removed in a future release. Please use .at[] or .iat[] accessors instead
#   del sys.path[0]
#                City Country   Latitude   Longitude
# 0        port blair      in   9.578608   93.658857
# 1      punta arenas      cl -55.632717  -86.089127
# 2           pokhara      np  31.836138   85.252430
# 3    merthyr tydfil      gb  51.740951   -3.420039
# 4         cape town      za -56.863703  -15.733949
# ..              ...     ...        ...         ...
# 495       gushikawa      jp  25.340271  129.525499
# 496          gilazi      az  40.723581   48.978129
# ...

# %%
new_data_cities = cities_list.drop_duplicates("City",keep="first")
len(new_data_cities)
# Out:
# 498

# %% [markdown]
# ### Perform API Calls
# * Perform a weather check on each city using a series of successive API calls.
# * Include a print log of each city as it'sbeing processed (with the city number and city name).

# %%
# OpenWeatherMap API Key
api_key = weather_api_key

# Starting URL for Weather Map API Call
url = "http://maps.openweathermap.org/maps/2.0/weather" + api_key

# %% [markdown]
# ### Convert Raw Data to DataFrame
# * Export the city data into a .csv.
# * Display the DataFrame

# %%
#create empty arrays to store the data for temperature, humidity, clouds, and wind speed 
temp = []
humidity =[]
clouds = []
wind = []

counter = 0
url = "http://maps.openweathermap.org/maps/2.0/weather" + api_key
units = "imperial"

#iterate through the rows to pull data from the api 
for index, row in new_data_cities.iterrows():
    counter +=1
    city = row["City"]
    target_url = url+city+"&appid="+"&units="+units
    print("City number "+str(counter))
    print("The name of the city is "+row["City"])
    print(target_url)
    print("__________________________________________________________________________________________")
# Out:
# City number 1
# The name of the city is port blair
# http://maps.openweathermap.org/maps/2.0/weatherf38ebf19e5a6af5c95abeffe4121238eport blair&appid=&units=imperial
# __________________________________________________________________________________________
# City number 2
# The name of the city is punta arenas
# http://maps.openweathermap.org/maps/2.0/weatherf38ebf19e5a6af5c95abeffe4121238epunta arenas&appid=&units=imperial
# __________________________________________________________________________________________
# City number 3
# The name of the city is pokhara
# http://maps.openweathermap.org/maps/2.0/weatherf38ebf19e5a6af5c95abeffe4121238epokhara&appid=&units=imperial
# __________________________________________________________________________________________
# City number 4
# The name of the city is merthyr tydfil
# http://maps.openweathermap.org/maps/2.0/weatherf38ebf19e5a6af5c95abeffe4121238emerthyr tydfil&appid=&units=imperial
# ...

# %%
city= []
clouds= []
country= []
date= []
humidity= []
lat= []
lng= []
temp= []
wind= []


weather_dict = {"City": city,
                "Cloudiness": clouds,
                "Country": country,
                "Humidity": humidity,
                "Lat": lat,
                "Lng": lng,
                "Temperature (°F)": temp,
                "Wind Speed": wind}
weather_data_df = pd.DataFrame(weather_dict)
weather_data_df=weather_data_df[["City","Country","Lat","Lng","Temperature (°F)","Humidity","Wind Speed","Cloudiness"]]



weather_data_df.head()
# Out:
# Empty DataFrame
# Columns: [City, Country, Lat, Lng, Temperature (°F), Humidity, Wind Speed, Cloudiness]
# Index: []

# %% [markdown]
# ### Plotting the Data
# * Use proper labeling of the plots using plot titles (including date of analysis) and axes labels.
# * Save the plotted figures as .pngs.

# %% [markdown]
# #### Latitude vs. Temperature Plot

# %% [markdown]
# #### Latitude vs. Humidity Plot

# %% [markdown]
# #### Latitude vs. Cloudiness Plot

# %% [markdown]
# #### Latitude vs. Wind Speed Plot

# %% [markdown]
# ## Linear Regression

# %%
# OPTIONAL: Create a function to create Linear Regression plots

# %%
# Create Northern and Southern Hemisphere DataFrames

# %% [markdown]
# ####  Northern Hemisphere - Max Temp vs. Latitude Linear Regression

# %% [markdown]
# ####  Southern Hemisphere - Max Temp vs. Latitude Linear Regression

# %% [markdown]
# ####  Northern Hemisphere - Humidity (%) vs. Latitude Linear Regression

# %% [markdown]
# ####  Southern Hemisphere - Humidity (%) vs. Latitude Linear Regression

# %% [markdown]
# ####  Northern Hemisphere - Cloudiness (%) vs. Latitude Linear Regression

# %% [markdown]
# ####  Southern Hemisphere - Cloudiness (%) vs. Latitude Linear Regression

# %% [markdown]
# ####  Northern Hemisphere - Wind Speed (mph) vs. Latitude Linear Regression

# %% [markdown]
# ####  Southern Hemisphere - Wind Speed (mph) vs. Latitude Linear Regression
